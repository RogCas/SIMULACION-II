# %% [markdown]
# <a href="https://colab.research.google.com/github/RogCas/SIMULACION-II/blob/main/Serpientes%20y%20Escaleras%20(20%20casillas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simulacion
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import random

def serpiente(lista, posicion):
    for i, num in enumerate(lista):
        if num == posicion:
            posicion = i
        break
    return posicion

"""num_serpientes = int(input("Cuantas serpientes hay: "))

num_escaleras = int(input("Cuantas escaleras hay: "))

serpientes_entrada = [0] * num_serpientes
serpientes_salida = [0] * num_serpientes

escaleras_entrada = [0] * num_escaleras
escaleras_salida = [0] * num_escaleras


for i in range(num_serpientes):
    serpientes_entrada[i] = int(input("Donde empieza tu {}  serpiente: ".format(i+1)))
    serpientes_salida[i] = int(input("Donde termina tu {}  serpiente: ".format(i+1)))

for i in range(num_escaleras):
    escaleras_entrada[i] = int(input("Donde empieza tu {}  escalera: ".format(i+1)))
    escaleras_salida[i] = int(input("Donde termina tu {}  escalera: ".format(i+1)))


serpientes_entrada = [16, 48, 49, 56, 62, 64, 87, 93, 95, 98]
serpientes_salida = [6, 26, 11, 53, 19, 60, 24, 73, 75, 78]

escaleras_entrada = [1, 4, 9, 21, 28, 36, 51, 71, 80]
escaleras_salida = [38, 14, 31, 42, 84, 44, 67, 91, 100]
"""
serpientes_entrada = [13,17]
serpientes_salida = [4,10]

escaleras_entrada = [3,15]
escaleras_salida = [11,19]

def juego():
    posicion_actual = 0
    contador = 0

    #print(serpiente(serpientes_entrada,posicion_actual))
    while posicion_actual < casillas:
        dado = random.randint(1,6)*ndados
        posicion_actual = posicion_actual + dado

        if posicion_actual in serpientes_entrada:
            i = serpientes_entrada.index(posicion_actual)
            posicion_actual = serpientes_salida[i]
        elif posicion_actual in escaleras_entrada:
            i2 = escaleras_entrada.index(posicion_actual)
            posicion_actual = escaleras_salida[i2]

        #print("En la jugada ", contador," avanzo ", dado,". Tu posición es: ", posicion_actual)
        contador += 1

    return contador
casillas=20
ndados=1
n = 100000

sim = 0

for i in range(n):
    sim  += juego()

print("El numero de jugadas para terminar el juego en promedio es de :",sim/n, " jugadas")
# Out:
# El numero de jugadas para terminar el juego en promedio es de : 7.05848  jugadas

# %% [markdown]
# #ANALITICAMENTE

# %% [markdown]
# Hacemos la Matriz de Probabilidades de Transicion

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hacemos la resta

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sacamos su inversa

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sumamos todos los elementos de la fila 1

# %% [markdown]
# Esta es la matriz F ya que esta nos da el numero promedio de periodos que se espera pasar en cada estado antes de caer en un estado absorbente

# %% [markdown]
# Nos da como resultado 7.06346313658
